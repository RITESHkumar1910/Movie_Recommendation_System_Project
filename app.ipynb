# %%
import streamlit as st

# %%
st.title('Movie Recommender System')
# Out:
# 2026-04-20 05:18:11.289 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-20 05:18:12.536
# ...
#   command:
#
#     streamlit run c:\Users\Igrit\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-20 05:18:12.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-20 05:18:12.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
